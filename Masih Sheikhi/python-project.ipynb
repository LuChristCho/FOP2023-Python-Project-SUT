# %% [markdown]
#   <div dir=rtl>
#     <img src="https://github.com/MoeeinAali/FOP2023-Python-Project-SUT/blob/main/public/Logo.png?raw=true" style="width: 20%;">
#   </div>
#   <br>
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <font face="IranSansX" size=6>
#         <b>پروژه درس مبانی برنامه‌سازی پایتون</b>
#             <font face="IranSansX" size=3>(نیم‌سال اول سال تحصیلی 02-03)</font>
#         </font><br>
#         <br>
#                 <font face="IranSansX" size=4>نام استاد: <b>آرمان ملک‌زاده </b></font>
#         <br>
#         <font face="IranSansX" size=4>سردستیاران آموزشی: <b>ایمان محمدی - علی ثالثی </b></font>
#         <br>
#         <font face="IranSansX" size=4>مسئول پروژه: <b> معین آعلی</b></font>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         </font>
#                     <font face="IranSansX" size=5 color=#006bcf>
#                         <b>اطلاعات دانشجو</b>
#                         <br>
#     </font>
#                 <font face="IranSansX" size=4 color=#006bcf>نام و نام‌خانوادگی:
#                     <b>
#                         مسیح
#                         شیخی
#                     </b>
#         </font>
#         <br>
#         </font>
#                 <font face="IranSansX" size=4 color=#006bcf>شماره دانشجویی:
#     402100859
#         </font>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b><font color=#cf1f00 size=4>توضیحات پروژه</font></b>
#         <hr/>
#        پروژه‌ی تحلیل داده که برای دانشجویان درس مبانی برنامه‌نویسی طراحی شده است، یک فرصت فوق‌العاده برای آشنایی با مفاهیم و فرایندهای مهم در حوزه‌ی تحلیل داده‌ها به دانشجویان ارائه می‌دهد. این پروژه برای دانشجوان این امکان را فراهم می‌کند تا با مراحل مختلف تحلیل داده آشنا شوند، از جمع‌آوری داده‌ها و تمیزکاری آن‌ها تا استفاده از الگوریتم‌ها و روش‌های تحلیلی متنوع برای استخراج اطلاعات مفید و الگوهای مهم. این پروژه نه‌تنها به دانشجویان این امکان را می‌دهد تا مهارت‌های برنامه نویسی خود را به کار بگیرند، بلکه با استفاده از ابزارهای نرم‌افزاری و تکنولوژی‌های مختلف، اطلاعات تحلیلی خود را به شیوه‌های مختلف و قابل فهم برای دیگران نمایش دهند. این پروژه از طریق تحلیل داده‌ها، دانشجویان را با ابزارها و فنون مرتبط با این حوزه آشنا می‌کند و امکان پیدا کردن الگوها و اطلاعات ارزشمند در داده‌ها را فراهم می‌سازد که این موارد می‌تواند در فرآیند تصمیم‌گیری‌های آینده‌ی شغلی و تحصیلی دانشجویان تأثیرگذار باشد.
#         <br>
#         دیتاست مورد استفاده در این پروژه شامل اطلاعات تعدادی از خانه‌های شهر تهران است که برای فروش آگهی شده بودند.
#         این دیتاست شامل مواردی همچون محله، قیمت، متراژ و بعضی از ویژگی‌های خاص هر خانه مانند انباری، آسانسور و ... است.
#          <br>
#         در این پروژه ما داد‌ها را تحلیل می‌کنیم و اطلاعاتی از وضعیت خانه‌های آگهی شده‌ی شهر تهران بدست می‌آوریم.
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b><font color=#cf1f00 size=4>نحوه تحویل پروژه</font></b>
#         <hr/>
#         دیتاست مورد استفاده در این پروژه در قالب یک فایل csv در اختیار شما قرار داده شده است.
#         <br>
#         برای تحویل پروژه لازم است که این NoteBook را تا ساعت 23:59 تاریخ 27 دی‌ماه تکمیل کرده و فایل آن را در کوئرا آپلود کنید.
#         دقت کنید که این پروژه 3 نمره از بارم‌بندی کل درس را شامل می‌شود، درنتیجه انتظار می‌روند به نسبت نمره‌ی اختصاص داده شده، برای پروژه وقت گذاشته شود.
#         دقت کنید که پس از اپلود پروژه در کوئرا، باید پروژه را برای تیم تدریس درس ارائه دهید، پس سعی کنید کدهایی که می‌زنید را متوجه شوید و به خوبی درک کنید و برای ارائه‌ی آن‌ها آماده باشید.
#         <br>
#         توجه داشته باشید که در صورت ابراز تقلب شما هنگام تحویل پروژه، مطابق با آیین‌نامه‌ی درس با شما برخورد خواهد شد.
#         <br>
#         شما
#         می‌توانید از هوش مصنوعی و گوگل برای یادگیری مطالب این پروژه استفاده کنید، اما الزامی است که کدهای این NoteBook توسط خودتان زده شده باشد.
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b><font color=#cf0000 size=4>نصب کتابخانه‌های مورد نیاز</font><b>
#         <hr/>
#             برای نصب کتابخانه‌های مورد نیاز در این پروژه، از pip استفاده می‌کنیم. بنابراین در ابتدا لازم است از نصب بودن pip برروی سیستم خود مطمئن شوید.
#             <a href="https://phoenixnap.com/kb/install-pip-windows">می‌توانید از این لینک کمک بگیرید.</a>
# <br>
#         حال که pip را نصب کردید می‌توانید اقدام به نصب کتابخانه‌های مورد نیاز بکنید.
#         در این پروژه پیش‌بینی می‌شود که از نیازمند استفاده از کتابخانه‌هایی همچون numpy و pandas و matplotlib و seaborn باشید.
#         البته شما آزاد هستید از دیگر کتابخانه‌های پایتون نیز استفاده کنید.
# > >             برای نصف کتابخانه‌های فوق به کمک pip، می‌توانید از دستور زیر استفاده کنید:
#     </font>
# </div>

# %%
# !pip install matplotlib seaborn pandas numpy
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.4)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b>
#         <font color=#006bcf size=5>فاز اول پروژه: </font>
#         <font color=#006bcf size=5>
#         Data Analysis
#         </font>
#         </b>
#         <br><br>
#          <font face="IranSansX" size=3>
# بخش تحلیل داده‌ها در این پروژه، به عنوان یک قسمت بسیار مهم و جذاب، به دانشجو فرصت می‌دهد تا از مفاهیم و تکنیک‌های بنیادی در حوزه‌ی تحلیل داده‌ها استفاده کند. این بخش شامل فرآیندهای مربوط به جمع‌آوری، تمیزکاری، تحلیل و نمایش داده‌ها است که از روش‌ها و ابزارهای مختلفی می‌توان برای این منظور استفاده کرد. با اعمال الگوریتم‌ها، روش‌های مختلف محاسباتی و ابزارهای نرم‌افزاری مناسب، دانشجوان قادر خواهند بود تا داده‌های خود را تجزیه و تحلیل کرده، الگوها و اطلاعات مفیدی را کشف کرده و درک عمیق‌تری از داده‌ها و مسائل مورد بررسی در پروژه خود پیدا کنند. این فرآیند به آن‌ها کمک می‌کند تا تصمیم‌گیری‌های بهتری بر اساس داده‌های موجود انجام دهند و نتایج موثرتری را به‌دست آورند.            </font>
#         <hr/>
#         <hr/>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# کتابخانه‌هایی که در مرحله قبل نصب کردید را داخل نوت‌بوک import کنید و برای هر کدام یک نام مخفف مانند sns, plt, np, pd و... در نظر بگیرید.    </font>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# دیتاست موجود در پروژه که یک فایل csv است را به صورت یک دیتافریم در متغیری به نام df بخوانید.
#     </font>
# </div>

# %%
df = pd.read_csv('/kaggle/input/houseprice-fop-project/housePrice.csv')

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ابعاد (تعداد سطرها و تعداد ستون‌ها) دیتافریم را به صورت یک tuple نمایش دهید.
#     </font>
# </div>

# %%
print(df.shape)
# Out:
# (3477, 8)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم را چاپ کنید.
#     </font>
# </div>

# %%
print(df)
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3472   86     2     True       True      True  Southern Janatabad
# 3473   83     2     True       True      True            Niavaran
# 3474   75     2    False      False     False              Parand
# 3475  105     2     True       True      True              Dorous
# 3476   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# 4     7.000000e+09   233333.33
# ...            ...         ...
# 3472  3.500000e+09   116666.67
# 3473  6.800000e+09   226666.67
# 3474  3.650000e+08    12166.67
# 3475  5.600000e+09   186666.67
# 3476  3.600000e+08    12000.00
#
# [3477 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ده سطر اول دیتافریم را چاپ کنید.
#     </font>
# </div>

# %%
print(df.head(10))
# Out:
#   Area  Room  Parking  Warehouse  Elevator                     Address  \
# 0   63     1     True       True      True                     Shahran
# 1   60     1     True       True      True                     Shahran
# 2   79     2     True       True      True                      Pardis
# 3   95     2     True       True      True               Shahrake Qods
# 4  123     2     True       True      True              Shahrake Gharb
# 5   70     2     True       True     False  North Program Organization
# 6   87     2     True       True      True                      Pardis
# 7   59     1     True       True      True                     Shahran
# 8   54     2     True       True     False                    Andisheh
# 9   71     1     True       True      True      West Ferdows Boulevard
#
#           Price  Price(USD)
# 0  1.850000e+09    61666.67
# 1  1.850000e+09    61666.67
# 2  5.500000e+08    18333.33
# 3  9.025000e+08    30083.33
# 4  7.000000e+09   233333.33
# 5  2.050000e+09    68333.33
# 6  6.000000e+08    20000.00
# 7  2.150000e+09    71666.67
# 8  4.930000e+08    16433.33
# 9  2.370000e+09    79000.00

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# ده سطر آخر دیتافریم را چاپ کنید.
#     </font>
# </div>

# %%
print(df.tail(10))
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 3467   74     2     True       True      True              Mehran
# 3468   97     2     True       True      True             Shahran
# 3469   94     2     True       True      True            Niavaran
# 3470  113     3     True       True      True         Ostad Moein
# 3471   63     1     True       True     False         Feiz Garden
# 3472   86     2     True       True      True  Southern Janatabad
# 3473   83     2     True       True      True            Niavaran
# 3474   75     2    False      False     False              Parand
# 3475  105     2     True       True      True              Dorous
# 3476   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 3467  4.070000e+09   135666.67
# 3468  2.700000e+09    90000.00
# 3469  8.450000e+09   281666.67
# 3470  3.170000e+09   105666.67
# 3471  1.890000e+09    63000.00
# 3472  3.500000e+09   116666.67
# 3473  6.800000e+09   226666.67
# 3474  3.650000e+08    12166.67
# 3475  5.600000e+09   186666.67
# 3476  3.600000e+08    12000.00

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ده سطر از دیتافریم را به صورت تصادفی (Random) انتخاب کرده و آن‌ها را در قالب یک دیتافریم با نام sample_df ذخیره کرده و آن را خروجی دهید.
#     </font>
# </div>

# %%
df.sample(10).to_csv('sample_df.csv', index=False)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# با یک دستور، اطلاعاتی کلی همانند نام ستون‌ها، تعداد indexها، تعداد سلول‌های non-null و... راجع به دیتافریم را بدست اورید.    </font>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3477 entries, 0 to 3476
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3477 non-null   object
#  1   Room        3477 non-null   int64
#  2   Parking     3477 non-null   bool
#  3   Warehouse   3477 non-null   bool
#  4   Elevator    3477 non-null   bool
#  5   Address     3454 non-null   object
#  6   Price       3477 non-null   float64
#  7   Price(USD)  3477 non-null   float64
# dtypes: bool(3), float64(2), int64(1), object(2)
# memory usage: 146.1+ KB

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         با یک دستور، اطلاعاتی کلی همانند مقدار ماکزیمم، مینیمم، میانگین، چارک‌ها و... راجع به ستون‌های دیتافریم بدست آورید.
#     </font>
# </div>

# %%
df.describe()
# Out:
#               Room         Price    Price(USD)
# count  3477.000000  3.477000e+03  3.477000e+03
# mean      2.079666  5.356506e+09  1.785502e+05
# std       0.758332  8.100118e+09  2.700039e+05
# min       0.000000  3.600000e+06  1.200000e+02
# 25%       2.000000  1.417500e+09  4.725000e+04
# 50%       2.000000  2.891700e+09  9.639000e+04
# 75%       2.000000  6.000000e+09  2.000000e+05
# max       5.000000  9.240000e+10  3.080000e+06

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         تعداد سلول‌های خالی در هر ستون از دیتافریم را خروجی دهید.
#     </font>
# </div>

# %%
cells_count = df.isnull().sum()
print(cells_count)
# Out:
# Area           0
# Room           0
# Parking        0
# Warehouse      0
# Elevator       0
# Address       23
# Price          0
# Price(USD)     0
# dtype: int64

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# آن سلول‌هایی که خالی هستند را از دیتافریم حذف کنید و دیتافریم جدید را جایگزین قبلی کنید.    </font>
# </div>

# %%
df = df.dropna()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         با یک دستور، جنس متغیر ذخیره‌شده در هر ستون از دیتافریم را نشان دهید.
#     </font>
# </div>

# %%
df.dtypes
# Out:
# Area           object
# Room            int64
# Parking          bool
# Warehouse        bool
# Elevator         bool
# Address        object
# Price         float64
# Price(USD)    float64
# dtype: object

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# جنس مقادیر ستون‌های  Area و Price  و Price(USD) را از رشته به مقدار عددی تغییر دهید و دیتافریم جدید را جایگزین قبلی کنید.    </font>
# </div>

# %%
df['Area'] = pd.to_numeric(df['Area'].str.replace(',', ''), errors='coerce')
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['Price(USD)'] = pd.to_numeric(df['Price(USD)'], errors='coerce')

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ستون‌هایی که جنس متغیر آن‌ها از نوع Boolean است را به مقادیر عددی تغییر دهید و دیتافریم جدید را جایگزین قبلی کنید. (به ازای True مقدار 1 و به ازای False مقدار 0 جایگزین شود.)
#     </font>
# </div>

# %%
bool_columns = df.select_dtypes(include='bool').columns
df[bool_columns] = df[bool_columns].astype(bool).astype(int)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم جدیدی تشکیل دهید به طوری که نام ستون‌های دیتافریم اصلی در ابتدای سطرها قرار گیرد و اطلاعاتی همانند min , max , mean و... که در قسمت‌های قبلی بدست آوردیم را به عنوان ستون‌های دیتافریم جدید قرار دهید. این دیتافریم جدید را در متغیری با نام df_T ذخیره کنید و چاپ کنید.
#     </font>
# </div>

# %%
df_T = df.describe().transpose()
df_T
# Out:
#              count          mean           std        min           25%  \
# Area        3454.0  3.170346e+06  1.493569e+08       30.0  6.900000e+01
# Room        3454.0  2.081065e+00  7.597806e-01        0.0  2.000000e+00
# Parking     3454.0  8.474233e-01  3.596311e-01        0.0  1.000000e+00
# Warehouse   3454.0  9.148813e-01  2.790987e-01        0.0  1.000000e+00
# Elevator    3454.0  7.872032e-01  4.093444e-01        0.0  1.000000e+00
# Price       3454.0  5.377435e+09  8.121933e+09  3600000.0  1.420000e+09
# Price(USD)  3454.0  1.792478e+05  2.707311e+05      120.0  4.733333e+04
#
#                      50%           75%           max
# Area        9.000000e+01  1.200000e+02  8.400000e+09
# Room        2.000000e+00  2.000000e+00  5.000000e+00
# Parking     1.000000e+00  1.000000e+00  1.000000e+00
# Warehouse   1.000000e+00  1.000000e+00  1.000000e+00
# Elevator    1.000000e+00  1.000000e+00  1.000000e+00
# Price       2.900000e+09  6.000000e+09  9.240000e+10
# Price(USD)  9.666667e+04  2.000000e+05  3.080000e+06

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نام ستون‌های دیتافریم را در یک لیست با نام column_names ذخیره کنید و سپس لیست را چاپ کنید.
#     </font>
# </div>

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['Area', 'Room', 'Parking', 'Warehouse', 'Elevator', 'Address', 'Price', 'Price(USD)']

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک دیکشنری از نام ستون‌ها تشکیل داده و نام هر ستون را به عنوان key و نام هر ستون به صورت Pascal case را به عنوان value آن در نظر بگیرید.(این
#         دیکشنری در مراحل بعدی مورد استفاده قرار می‌گیرد.)
#         <br>
#         </font>
#         <font face="IranSansX" size=2>
#         <a href="https://stackoverflow.com/questions/17326185/what-are-the-different-kinds-of-cases">می‌توانید از این لینک برای آشنایی با Case Styleها استفاده کنید.</a>
#     </font>
# </div>

# %%
column_names_pascal = {col: ''.join(word.capitalize() for word in col.split()) for col in column_names}
print(column_names_pascal)
# Out:
# {'Area': 'Area', 'Room': 'Room', 'Parking': 'Parking', 'Warehouse': 'Warehouse', 'Elevator': 'Elevator', 'Address': 'Address', 'Price': 'Price', 'Price(USD)': 'Price(usd)'}

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نام ستون‌هایی که طول آن‌ها از 8 کارکتر کمتر است را خروجی دهید.
#     </font>
# </div>

# %%
short_column_names = [col for col in column_names if len(col) < 8]
print(*short_column_names)
# Out:
# Area Room Parking Address Price

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نام تمامی ستون‌ها را به صورت یک رشته‌ که نام هر ستون با کارکتر '-' از دیگری جدا شده، خروجی دهید.    </font>
# </div>

# %%
columns_as_string = '-'.join(column_names)
print(columns_as_string)
# Out:
# Area-Room-Parking-Warehouse-Elevator-Address-Price-Price(USD)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# با استفاده از دیکشنری ایجاد شده در مراحل قبل، نام ستون‌های دیتافریم را به صورت Pascal case تغییر دهید و در df ذخیره کنید.
#     </font>
# </div>

# %%
df.rename(columns=column_names_pascal, inplace=True)

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ستون‌های مربوط به قیمت را حذف کرده و دیتافریم حاصل را در متغیری به نام df_without_price ذخیره کنید.
#     </font>
# </div>

# %%
df_without_price = df.drop(columns=['Price', 'Price(usd)'])

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم df_without_price را چاپ کنید.
#     </font>
# </div>

# %%
print(df_without_price)
# Out:
#       Area  Room  Parking  Warehouse  Elevator             Address
# 0       63     1        1          1         1             Shahran
# 1       60     1        1          1         1             Shahran
# 2       79     2        1          1         1              Pardis
# 3       95     2        1          1         1       Shahrake Qods
# 4      123     2        1          1         1      Shahrake Gharb
# ...    ...   ...      ...        ...       ...                 ...
# 3472    86     2        1          1         1  Southern Janatabad
# 3473    83     2        1          1         1            Niavaran
# 3474    75     2        0          0         0              Parand
# 3475   105     2        1          1         1              Dorous
# 3476    82     2        0          1         1              Parand
#
# [3454 rows x 6 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ستون‌های Area و Room و Price را در قالب یک دیتافریم جدید خروجی دهید.
#     </font>
# </div>

# %%
selected_columns = ['Area', 'Room', 'Price']
df_selected_columns = df[selected_columns]
df_selected_columns.to_csv('selected_columns.csv', index=False)
df_selected_columns
# Out:
#       Area  Room         Price
# 0       63     1  1.850000e+09
# 1       60     1  1.850000e+09
# 2       79     2  5.500000e+08
# 3       95     2  9.025000e+08
# 4      123     2  7.000000e+09
# ...    ...   ...           ...
# 3472    86     2  3.500000e+09
# 3473    83     2  6.800000e+09
# 3474    75     2  3.650000e+08
# 3475   105     2  5.600000e+09
# 3476    82     2  3.600000e+08
#
# [3454 rows x 3 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# سطرهایی از دیتافریم df که index زوج دارند را در قالب یک دیتافریم خروجی دهید.
#     </font>
# </div>

# %%
df_even_index = df[df.index % 2 == 0]
df_even_index.to_csv('even_index_rows.csv', index=False)
df_even_index
# Out:
#       Area  Room  Parking  Warehouse  Elevator             Address  \
# 0       63     1        1          1         1             Shahran
# 2       79     2        1          1         1              Pardis
# 4      123     2        1          1         1      Shahrake Gharb
# 6       87     2        1          1         1              Pardis
# 8       54     2        1          1         0            Andisheh
# ...    ...   ...      ...        ...       ...                 ...
# 3468    97     2        1          1         1             Shahran
# 3470   113     3        1          1         1         Ostad Moein
# 3472    86     2        1          1         1  Southern Janatabad
# 3474    75     2        0          0         0              Parand
# 3476    82     2        0          1         1              Parand
#
#              Price  Price(usd)
# 0     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 4     7.000000e+09   233333.33
# 6     6.000000e+08    20000.00
# 8     4.930000e+08    16433.33
# ...            ...         ...
# 3468  2.700000e+09    90000.00
# 3470  3.170000e+09   105666.67
# 3472  3.500000e+09   116666.67
# 3474  3.650000e+08    12166.67
# 3476  3.600000e+08    12000.00
#
# [1730 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         تعداد مقادیر متمایز موجود در هر ستون را در قالب یک دیکشنری با نام دلخواه ذخیره کنید و خروجی دهید.(در دیکشنری key برابر است با نام ستون و value تعداد مقادیر متمایز موجود در آن است.)
#     </font>
# </div>

# %%
unique_values_dict = {col: df[col].nunique() for col in df.columns}
print(unique_values_dict)
# Out:
# {'Area': 241, 'Room': 6, 'Parking': 2, 'Warehouse': 2, 'Elevator': 2, 'Address': 192, 'Price': 928, 'Price(usd)': 926}

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         تمامی مقادیر متمایز موجود در ستون Address را در قالب یک لیست خروجی دهید.
#     </font>
# </div>

# %%
unique_values_in_address = df['Address'].unique().tolist()
print(unique_values_in_address)
# Out:
# ['Shahran', 'Pardis', 'Shahrake Qods', 'Shahrake Gharb', 'North Program Organization', 'Andisheh', 'West Ferdows Boulevard', 'Narmak', 'Saadat Abad', 'Zafar', 'Islamshahr', 'Pirouzi', 'Shahrake Shahid Bagheri', 'Moniriyeh', 'Velenjak', 'Amirieh', 'Southern Janatabad', 'Salsabil', 'Zargandeh', 'Feiz Garden', 'Water Organization', 'ShahrAra', 'Gisha', 'Ray', 'Abbasabad', 'Ostad Moein', 'Farmanieh', 'Parand', 'Punak', 'Qasr-od-Dasht', 'Aqdasieh', 'Pakdasht', 'Railway', 'Central Janatabad', 'East Ferdows Boulevard', 'Pakdasht KhatunAbad', 'Sattarkhan', 'Baghestan', 'Shahryar', 'Northern Janatabad', 'Daryan No', 'Southern Program Organization', 'Rudhen', 'West Pars', 'Afsarieh', 'Marzdaran', 'Dorous', 'Sadeghieh', 'Chahardangeh', 'Baqershahr', 'Jeyhoon', 'Lavizan', 'Shams Abad', 'Fatemi', 'Keshavarz Boulevard', 'Kahrizak', 'Qarchak', 'Northren Jamalzadeh', 'Azarbaijan', 'Bahar', 'Persian Gulf Martyrs Lake', 'Beryanak', 'Heshmatieh', 'Elm-o-Sanat', 'Golestan', 'Shahr-e-Ziba', 'Pasdaran', 'Chardivari', 'Gheitarieh', 'Kamranieh', 'Gholhak', 'Heravi', 'Hashemi', 'Dehkade Olampic', 'Damavand', 'Republic', 'Zaferanieh', 'Qazvin Imamzadeh Hassan', 'Niavaran', 'Valiasr', 'Qalandari', 'Amir Bahador', 'Ekhtiarieh', 'Ekbatan', 'Absard', 'Haft Tir', 'Mahallati', 'Ozgol', 'Tajrish', 'Abazar', 'Koohsar', 'Hekmat', 'Parastar', 'Lavasan', 'Majidieh', 'Southern Chitgar', 'Karimkhan', 'Si Metri Ji', 'Karoon', 'Northern Chitgar', 'East Pars', 'Kook', 'Air force', 'Sohanak', 'Komeil', 'Azadshahr', 'Zibadasht', 'Amirabad', 'Dezashib', 'Elahieh', 'Mirdamad', 'Razi', 'Jordan', 'Mahmoudieh', 'Shahedshahr', 'Yaftabad', 'Mehran', 'Nasim Shahr', 'Tenant', 'Chardangeh', 'Fallah', 'Eskandari', 'Shahrakeh Naft', 'Ajudaniye', 'Tehransar', 'Nawab', 'Yousef Abad', 'Northern Suhrawardi', 'Villa', 'Hakimiyeh', 'Nezamabad', 'Garden of Saba', 'Tarasht', 'Azari', 'Shahrake Apadana', 'Araj', 'Vahidieh', 'Malard', 'Shahrake Azadi', 'Darband', 'Vanak', 'Tehran Now', 'Darabad', 'Eram', 'Atabak', 'Sabalan', 'SabaShahr', 'Shahrake Madaen', 'Waterfall', 'Ahang', 'Salehabad', 'Pishva', 'Enghelab', 'Islamshahr Elahieh', 'Ray - Montazeri', 'Firoozkooh Kuhsar', 'Ghoba', 'Mehrabad', 'Southern Suhrawardi', 'Abuzar', 'Dolatabad', 'Hor Square', 'Taslihat', 'Kazemabad', 'Robat Karim', 'Ray - Pilgosh', 'Ghiyamdasht', 'Telecommunication', 'Mirza Shirazi', 'Gandhi', 'Argentina', 'Seyed Khandan', 'Shahrake Quds', 'Safadasht', 'Khademabad Garden', 'Hassan Abad', 'Chidz', 'Khavaran', 'Boloorsazi', 'Mehrabad River River', 'Varamin - Beheshti', 'Shoosh', 'Thirteen November', 'Darakeh', 'Aliabad South', 'Alborz Complex', 'Firoozkooh', 'Vahidiyeh', 'Shadabad', 'Naziabad', 'Javadiyeh', 'Yakhchiabad']

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# یک دیکشنری با نام دلخواه ایجاد کنید که key آن برابر با نام ستون‌های دیتافریم و value آن برابر است با لیستی از مقدار متمایز موجود در آن ستون از دیتافریم.در آخر دیکشنری را چاپ کنید.
#     </font>
# </div>

# %%
distinct_values_dict = {col: df[col].unique().tolist() for col in df.columns}
print(distinct_values_dict)
# Out:
# {'Area': [63, 60, 79, 95, 123, 70, 87, 59, 54, 71, 68, 64, 136, 155, 140, 42, 93, 65, 99, 105, 160, 77, 110, 100, 90, 49, 96, 67, 62, 55, 129, 109, 58, 150, 130, 88, 51, 113, 98, 75, 61, 72, 122, 215, 101, 53, 74, 114, 151, 300, 76, 148, 40, 128, 94, 97, 137, 85, 78, 48, 82, 120, 139, 66, 80, 44, 50, 121, 141, 127, 180, 158, 144, 245, 190, 108, 117, 200, 125, 236, 220, 86, 84, 106, 320, 154, 210, 124, 83, 270, 104, 103, 165, 135, 132, 81, 153, 166, 175, 170, 115, 118, 116, 43, 230, 91, 126, 450, 500, 145, 112, 192, 164, 265, 92, 143, 350, 335, 235, 225, 221, 312, 188, 198, 650, 179, 256, 257, 167, 246, 168, 280, 69, 400, 660, 213, 57, 102, 133, 73, 134, 191, 282, 89, 111, 147, 157, 283, 863, 415, 173, 162, 156, 171, 261, 45, 161, 46, 107, 420, 131, 185, 250, 216, 1000, 680, 750, 202, 138, 38, 56, 197, 52, 365, 181, 146, 240, 142, 303, 203, 204, 255, 194, 600, 377, 231, 195, 176, 290, 149, 238, 226, 574, 360, 37, 465, 403, 405, 41, 228, 177, 310, 193, 8400000000, 287, 929, 550, 47, 380, 182, 119, 705, 222, 152, 209, 232, 900, 201, 174, 3600, 39, 172, 35, 32, 211, 258, 700, 163, 208, 253, 33, 2550000000, 330, 212, 345, 530, 630, 30, 205, 285, 186], 'Room': [1, 2, 3, 0, 4, 5], 'Parking': [1, 0], 'Warehouse': [1, 0], 'Elevator': [1, 0], 'Address': ['Shahran', 'Pardis', 'Shahrake Qods', 'Shahrake Gharb', 'North Program Organization', 'Andisheh', 'West Ferdows Boulevard', 'Narmak', 'Saadat Abad', 'Zafar', 'Islamshahr', 'Pirouzi', 'Shahrake Shahid Bagheri', 'Moniriyeh', 'Velenjak', 'Amirieh', 'Southern Janatabad', 'Salsabil', 'Zargandeh', 'Feiz Garden', 'Water Organization', 'ShahrAra', 'Gisha', 'Ray', 'Abbasabad', 'Ostad Moein', 'Farmanieh', 'Parand', 'Punak', 'Qasr-od-Dasht', 'Aqdasieh', 'Pakdasht', 'Railway', 'Central Janatabad', 'East Ferdows Boulevard', 'Pakdasht KhatunAbad', 'Sattarkhan', 'Baghestan', 'Shahryar', 'Northern Janatabad', 'Daryan No', 'Southern Program Organization', 'Rudhen', 'West Pars', 'Afsarieh', 'Marzdaran', 'Dorous', 'Sadeghieh', 'Chahardangeh', 'Baqershahr', 'Jeyhoon', 'Lavizan', 'Shams Abad', 'Fatemi', 'Keshavarz Boulevard', 'Kahrizak', 'Qarchak', 'Northren Jamalzadeh', 'Azarbaijan', 'Bahar', 'Persian Gulf Martyrs Lake', 'Beryanak', 'Heshmatieh', 'Elm-o-Sanat', 'Golestan', 'Shahr-e-Ziba', 'Pasdaran', 'Chardivari', 'Gheitarieh', 'Kamranieh', 'Gholhak', 'Heravi', 'Hashemi', 'Dehkade Olampic', 'Damavand', 'Republic', 'Zaferanieh', 'Qazvin Imamzadeh Hassan', 'Niavaran', 'Valiasr', 'Qalandari', 'Amir Bahador', 'Ekhtiarieh', 'Ekbatan', 'Absard', 'Haft Tir', 'Mahallati', 'Ozgol', 'Tajrish', 'Abazar', 'Koohsar', 'Hekmat', 'Parastar', 'Lavasan', 'Majidieh', 'Southern Chitgar', 'Karimkhan', 'Si Metri Ji', 'Karoon', 'Northern Chitgar', 'East Pars', 'Kook', 'Air force', 'Sohanak', 'Komeil', 'Azadshahr', 'Zibadasht', 'Amirabad', 'Dezashib', 'Elahieh', 'Mirdamad', 'Razi', 'Jordan', 'Mahmoudieh', 'Shahedshahr', 'Yaftabad', 'Mehran', 'Nasim Shahr', 'Tenant', 'Chardangeh', 'Fallah', 'Eskandari', 'Shahrakeh Naft', 'Ajudaniye', 'Tehransar', 'Nawab', 'Yousef Abad', 'Northern Suhrawardi', 'Villa', 'Hakimiyeh', 'Nezamabad', 'Garden of Saba', 'Tarasht', 'Azari', 'Shahrake Apadana', 'Araj', 'Vahidieh', 'Malard', 'Shahrake Azadi', 'Darband', 'Vanak', 'Tehran Now', 'Darabad', 'Eram', 'Atabak', 'Sabalan', 'SabaShahr', 'Shahrake Madaen', 'Waterfall', 'Ahang', 'Salehabad', 'Pishva', 'Enghelab', 'Islamshahr Elahieh', 'Ray - Montazeri', 'Firoozkooh Kuhsar', 'Ghoba', 'Mehrabad', 'Southern Suhrawardi', 'Abuzar', 'Dolatabad', 'Hor Square', 'Taslihat', 'Kazemabad', 'Robat Karim', 'Ray - Pilgosh', 'Ghiyamdasht', 'Telecommunication', 'Mirza Shirazi', 'Gandhi', 'Argentina', 'Seyed Khandan', 'Shahrake Quds', 'Safadasht', 'Khademabad Garden', 'Hassan Abad', 'Chidz', 'Khavaran', 'Boloorsazi', 'Mehrabad River River', 'Varamin - Beheshti', 'Shoosh', 'Thirteen November', 'Darakeh', 'Aliabad South', 'Alborz Complex', 'Firoozkooh', 'Vahidiyeh', 'Shadabad', 'Naziabad', 'Javadiyeh', 'Yakhchiabad'], 'Price': [1850000000.0, 550000000.0, 902500000.0, 70000 ...

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         تعداد دفعات تکرار هر مقدار متمایز در ستون Address را مشخص کنید و نتایج را در یک دیکشنری ذخیره کرده و خروجی دهید.(در دیکشنری key برابر با نام مقادیر متمایز ستون Address و value برابر با تعداد دفعات تکرار آن است.)
#     </font>
# </div>

# %%
address_repetitions = df['Address'].value_counts().to_dict()
print(address_repetitions)
# Out:
# {'Punak': 161, 'Pardis': 146, 'West Ferdows Boulevard': 145, 'Gheitarieh': 141, 'Shahran': 130, 'Saadat Abad': 129, 'Parand': 127, 'Shahr-e-Ziba': 109, 'Southern Janatabad': 93, 'Central Janatabad': 91, 'Jeyhoon': 91, 'Persian Gulf Martyrs Lake': 88, 'Andisheh': 83, 'Ostad Moein': 82, 'East Ferdows Boulevard': 74, 'Shahrake Qods': 69, 'Niavaran': 68, 'Pasdaran': 66, 'Pirouzi': 63, 'Salsabil': 60, 'Shahrake Gharb': 59, 'Farmanieh': 57, 'Heravi': 46, 'Ekhtiarieh': 42, 'Islamshahr': 39, 'Yousef Abad': 38, 'Feiz Garden': 38, 'Northern Janatabad': 33, 'Qasr-od-Dasht': 28, 'North Program Organization': 27, 'Zaferanieh': 27, 'Beryanak': 25, 'Narmak': 25, 'Aqdasieh': 25, 'Pakdasht': 25, 'Azarbaijan': 24, 'Tenant': 23, 'Damavand': 23, 'Southern Program Organization': 23, 'Abazar': 23, 'Si Metri Ji': 23, 'Velenjak': 22, 'Marzdaran': 22, 'Karoon': 20, 'Jordan': 18, 'Elahieh': 17, 'Northern Chitgar': 16, 'Kahrizak': 16, 'Golestan': 16, 'Mirdamad': 15, 'Northren Jamalzadeh': 14, 'Kamranieh': 14, 'Amirabad': 14, 'Dorous': 13, 'Hashemi': 13, 'Shahryar': 13, 'Sattarkhan': 12, 'Amirieh': 12, 'Qazvin Imamzadeh Hassan': 11, 'Qalandari': 11, 'Rudhen': 11, 'West Pars': 11, 'Railway': 11, 'Komeil': 11, 'Air force': 10, 'Zafar': 10, 'Gholhak': 10, 'Ozgol': 10, 'Gisha': 9, 'Dezashib': 9, 'Ray': 9, 'Dehkade Olampic': 9, 'Araj': 9, 'Fallah': 9, 'Kook': 9, 'East Pars': 8, 'Tehransar': 8, 'Parastar': 8, 'Mehran': 8, 'Baghestan': 8, 'Shams Abad': 8, 'Valiasr': 7, 'Tajrish': 7, 'Razi': 7, 'Ekbatan': 7, 'Hor Square': 6, 'Tarasht': 6, 'Afsarieh': 6, 'Sadeghieh': 6, 'Absard': 6, 'Ajudaniye': 5, 'Hakimiyeh': 5, 'Shahedshahr': 5, 'Shahrake Quds': 5, 'Azadshahr': 5, 'ShahrAra': 5, 'Qarchak': 5, 'Southern Chitgar': 5, 'Keshavarz Boulevard': 4, 'Amir Bahador': 4, 'Northern Suhrawardi': 4, 'Tehran Now': 4, 'Water Organization': 4, 'Zargandeh': 4, 'Koohsar': 4, 'Republic': 4, 'Mahallati': 4, 'Lavasan': 4, 'Heshmatieh': 4, 'Eskandari': 4, 'Seyed Khandan': 3, 'Khavaran': 3, 'Waterfall': 3, 'Darabad': 3, 'Abuzar': 3, 'Shahrakeh Naft': 3, 'Atabak': 3, 'Karimkhan': 3, 'Fatemi': 3, 'Yaftabad': 3, 'Mahmoudieh': 3, 'Daryan No': 3, 'Elm-o-Sanat': 3, 'Ghoba': 2, 'Shoosh': 2, 'Sabalan': 2, 'Ahang': 2, 'Shahrake Shahid Bagheri': 2, 'Pishva': 2, 'Chidz': 2, 'Nasim Shahr': 2, 'Moniriyeh': 2, 'Vanak': 2, 'Dolatabad': 2, 'Abbasabad': 2, 'Taslihat': 2, 'Argentina': 2, 'Robat Karim': 2, 'Southern Suhrawardi': 2, 'Lavizan': 2, 'Nezamabad': 2, 'Malard': 2, 'Vahidieh': 2, 'Majidieh': 2, 'Nawab': 2, 'Hekmat': 2, 'Haft Tir': 2, 'Garden of Saba': 2, 'Shahrake Azadi': 2, 'Vahidiyeh': 2, 'Darakeh': 1, 'Gandhi': 1, 'Javadiyeh': 1, 'Naziabad': 1, 'Shadabad': 1, 'Hassan Abad': 1, 'Safadasht': 1, 'Khademabad Garden': 1, 'Firoozkooh': 1, 'Alborz Complex': 1, 'Aliabad South': 1, 'Boloorsazi': 1, 'Mehrabad River River': 1, 'Varamin - Beheshti': 1, 'Thirteen November': 1, 'Telecommunication': 1, 'Mirza Shirazi': 1, 'Firoozkooh Kuhsar': 1, 'Ghiyamdasht': 1, 'Ray - Pilgosh': 1, 'Zibadasht': 1, 'Sohanak': 1, 'Villa': 1, 'Chardivari': 1, 'Azari': 1, 'Shahrake Apadana': 1, 'Bahar': 1, 'Darband': 1, 'Eram': 1, 'Baqershahr': 1, 'SabaShahr': 1, 'Shahrake Madaen': 1, 'Chahardangeh': 1, 'Salehabad': 1, 'Enghelab': 1, 'Islamshahr Elahieh': 1, 'Ray - Montazeri': 1, 'Chardangeh': 1, 'Mehrabad': 1, 'Pakdasht KhatunAbad': 1, 'Kazemabad': 1, 'Yakhchiabad': 1}

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ماکزیمم، مینیمم و طول بازه‌ی تغییرات مقادیر ستون‌هایی که متغیر آن‌ها عددی است را چاپ کنید.
#     </font>
# </div>

# %%
numerical_columns = df.select_dtypes(include=['number']).columns
for col in numerical_columns:
    print(f"Column: {col}")
    print(f"Maximum value: {df[col].max()}")
    print(f"Minimum value: {df[col].min()}")
    print(f"Length of the interval: {df[col].max() - df[col].min()}\n")
# Out:
# Column: Area
# Maximum value: 8400000000
# Minimum value: 30
# Length of the interval: 8399999970
#
# Column: Room
# Maximum value: 5
# Minimum value: 0
# Length of the interval: 5
#
# Column: Parking
# Maximum value: 1
# Minimum value: 0
# Length of the interval: 1
#
# Column: Warehouse
# Maximum value: 1
# Minimum value: 0
# Length of the interval: 1
#
# Column: Elevator
# Maximum value: 1
# Minimum value: 0
# Length of the interval: 1
#
# Column: Price
# Maximum value: 92400000000.0
# Minimum value: 3600000.0
# Length of the interval: 92396400000.0
#
# Column: Price(usd)
# Maximum value: 3080000.0
# Minimum value: 120.0
# Length of the interval: 3079880.0

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         سطرهایی که مقدار Area آن‌ها از چارک اول مقادیر ستون Area کمتر است را در یک دیتافریم جدید با نام دلخواه ذخیره کرده و خروجی دهید.
#     </font>
# </div>

# %%
first_quartile = df['Area'].quantile(0.25)
df_less_than_first_quartile = df[df['Area'] < first_quartile]
df_less_than_first_quartile.to_csv('less_than_first_quartile.csv', index=False)
df_less_than_first_quartile
# Out:
#       Area  Room  Parking  Warehouse  Elevator                 Address  \
# 0       63     1        1          1         1                 Shahran
# 1       60     1        1          1         1                 Shahran
# 7       59     1        1          1         1                 Shahran
# 8       54     2        1          1         0                Andisheh
# 10      68     2        1          1         1  West Ferdows Boulevard
# ...    ...   ...      ...        ...       ...                     ...
# 3459    55     1        1          1         1                   Punak
# 3460    60     1        1          1         1  West Ferdows Boulevard
# 3463    68     2        0          1         1                Beryanak
# 3464    61     2        0          1         0                Andisheh
# 3471    63     1        1          1         0             Feiz Garden
#
#              Price  Price(usd)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 7     2.150000e+09    71666.67
# 8     4.930000e+08    16433.33
# 10    2.450000e+09    81666.67
# ...            ...         ...
# 3459  2.300000e+09    76666.67
# 3460  1.950000e+09    65000.00
# 3463  1.258000e+09    41933.33
# 3464  4.600000e+08    15333.33
# 3471  1.890000e+09    63000.00
#
# [861 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         همانند قسمت قبل، آن سطرهایی که Area آن‌ها از چارک اول کمتر است را شناسایی کرده و فقط مقادیر ستون‌های Area، Room و Price خروجی دهید.
#     </font>
# </div>

# %%
selected_columns = ['Area', 'Room', 'Price']
df_selected_values = df_less_than_first_quartile[selected_columns]
df_selected_values.to_csv('selected_values_less_than_first_quartile.csv', index=False)
df_selected_values
# Out:
#       Area  Room         Price
# 0       63     1  1.850000e+09
# 1       60     1  1.850000e+09
# 7       59     1  2.150000e+09
# 8       54     2  4.930000e+08
# 10      68     2  2.450000e+09
# ...    ...   ...           ...
# 3459    55     1  2.300000e+09
# 3460    60     1  1.950000e+09
# 3463    68     2  1.258000e+09
# 3464    61     2  4.600000e+08
# 3471    63     1  1.890000e+09
#
# [861 rows x 3 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم اولیه را برحسب ستون قیمت sort کنید و آن را در متغیری به نام df_sorted_by_price ذخیره کنید و در آخر خروجی دهید.
#     </font>
# </div>

# %%
df_sorted_by_price = df.sort_values(by='Price')
df_sorted_by_price.to_csv('df_sorted_by_price.csv', index=False)
df_sorted_by_price
# Out:
#       Area  Room  Parking  Warehouse  Elevator     Address         Price  \
# 136    160     1        0          0         0     Qarchak  3.600000e+06
# 2768    83     2        1          1         1       Ozgol  5.500000e+07
# 729     75     2        1          1         1      Pardis  6.000000e+07
# 2719   110     0        1          1         1      Parand  1.020000e+08
# 2199    49     1        1          1         0    Andisheh  1.100000e+08
# ...    ...   ...      ...        ...       ...         ...           ...
# 1330   350     4        1          1         1    Niavaran  8.050000e+10
# 817    680     5        1          1         0  Ekhtiarieh  8.160000e+10
# 430    400     5        1          1         0     Lavasan  8.500000e+10
# 1808   705     5        1          1         0      Abazar  9.100000e+10
# 1705   420     4        1          1         1  Zaferanieh  9.240000e+10
#
#       Price(usd)
# 136       120.00
# 2768     1833.33
# 729      2000.00
# 2719     3400.00
# 2199     3666.67
# ...          ...
# 1330  2683333.33
# 817   2720000.00
# 430   2833333.33
# 1808  3033333.33
# 1705  3080000.00
#
# [3454 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# دیتافریم df_sorted_by_price را به صورت معکوس خروجی دهید.(از آخر به اول)    </font>
# </div>

# %%
df_sorted_by_price_reverse = df_sorted_by_price[::-1]
df_sorted_by_price_reverse.to_csv('df_sorted_by_price_reverse.csv', index=False)
df_sorted_by_price_reverse
# Out:
#       Area  Room  Parking  Warehouse  Elevator     Address         Price  \
# 1705   420     4        1          1         1  Zaferanieh  9.240000e+10
# 1808   705     5        1          1         0      Abazar  9.100000e+10
# 430    400     5        1          1         0     Lavasan  8.500000e+10
# 817    680     5        1          1         0  Ekhtiarieh  8.160000e+10
# 1330   350     4        1          1         1    Niavaran  8.050000e+10
# ...    ...   ...      ...        ...       ...         ...           ...
# 2199    49     1        1          1         0    Andisheh  1.100000e+08
# 2719   110     0        1          1         1      Parand  1.020000e+08
# 729     75     2        1          1         1      Pardis  6.000000e+07
# 2768    83     2        1          1         1       Ozgol  5.500000e+07
# 136    160     1        0          0         0     Qarchak  3.600000e+06
#
#       Price(usd)
# 1705  3080000.00
# 1808  3033333.33
# 430   2833333.33
# 817   2720000.00
# 1330  2683333.33
# ...          ...
# 2199     3666.67
# 2719     3400.00
# 729      2000.00
# 2768     1833.33
# 136       120.00
#
# [3454 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         سطرهایی که مقدار ستون Elevator برای آن‌ها True است را برحسب قیمت sort کنید و خروجی دهید.
#     </font>
# </div>

# %%
df_with_elevator = df[df['Elevator'] == True]
df_sorted_with_elevator = df_with_elevator.sort_values(by='Price')
df_sorted_with_elevator
# Out:
#       Area  Room  Parking  Warehouse  Elevator     Address         Price  \
# 2768    83     2        1          1         1       Ozgol  5.500000e+07
# 729     75     2        1          1         1      Pardis  6.000000e+07
# 2719   110     0        1          1         1      Parand  1.020000e+08
# 1341    78     2        1          1         1      Parand  2.100000e+08
# 3430    58     1        0          0         1      Parand  2.460000e+08
# ...    ...   ...      ...        ...       ...         ...           ...
# 2392   310     3        1          1         1    Aqdasieh  7.440000e+10
# 829    750     5        1          1         1  Mahmoudieh  7.500000e+10
# 3049   530     4        1          1         1      Dorous  7.950000e+10
# 1330   350     4        1          1         1    Niavaran  8.050000e+10
# 1705   420     4        1          1         1  Zaferanieh  9.240000e+10
#
#       Price(usd)
# 2768     1833.33
# 729      2000.00
# 2719     3400.00
# 1341     7000.00
# 3430     8200.00
# ...          ...
# 2392  2480000.00
# 829   2500000.00
# 3049  2650000.00
# 1330  2683333.33
# 1705  3080000.00
#
# [2719 rows x 8 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم را برحسب Address گروه‌بندی کنید، سپس جمع Area خانه‌های هر گروه را محاسبه و خروجی دهید.
#     </font>
# </div>

# %%
area_sum_by_address = df.groupby('Address')['Area'].sum()
print(area_sum_by_address)
# Out:
# Address
# Abazar         2885
# Abbasabad       150
# Absard         3100
# Abuzar          184
# Afsarieh        491
#                ...
# Yousef Abad    4437
# Zafar          1879
# Zaferanieh     5293
# Zargandeh       485
# Zibadasht       115
# Name: Area, Length: 192, dtype: int64

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         دیتافریم را برحسب Address گروه‌بندی کنید، سپس میانگین Area خانه‌های هر گروه را با استفاده از Aggregate کردن گروه‌ها با تابع mean بیابید، سپس مقادیر بدست آمده را در یک دیتافریم جدید ذخیره کرده و خروجی دهید.
#     </font>
# </div>

# %%
avg_area_by_address = df.groupby('Address')['Area'].mean()
df_avg_area_by_address = avg_area_by_address.reset_index(name='Average_Area')
print(df_avg_area_by_address)
# Out:
#          Address  Average_Area
# 0         Abazar    125.434783
# 1      Abbasabad     75.000000
# 2         Absard    516.666667
# 3         Abuzar     61.333333
# 4       Afsarieh     81.833333
# ..           ...           ...
# 187  Yousef Abad    116.763158
# 188        Zafar    187.900000
# 189   Zaferanieh    196.037037
# 190    Zargandeh    121.250000
# 191    Zibadasht    115.000000
#
# [192 rows x 2 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک crosstab برحسب Room و Parking رسم کنید.
#     </font>
# </div>

# %%
crosstab_room_parking = pd.crosstab(df['Room'], df['Parking'])
print(crosstab_room_parking)
# Out:
# Parking    0     1
# Room
# 0          8     2
# 1        243   426
# 2        244  1698
# 3         26   704
# 4          1    69
# 5          5    28

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# یک crosstab برحسب Room و Warehouse رسم کنید.    </font>
# </div>

# %%
crosstab_room_warehouse = pd.crosstab(df['Room'], df['Warehouse'])
print(crosstab_room_warehouse)
# Out:
# Warehouse    0     1
# Room
# 0            5     5
# 1          109   560
# 2          149  1793
# 3           21   709
# 4            3    67
# 5            7    26

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک crosstab برحسب Room و Elevator رسم کنید.
#     </font>
# </div>

# %%
crosstab_room_elevator = pd.crosstab(df['Room'], df['Elevator'])
print(crosstab_room_elevator)
# Out:
# Elevator    0     1
# Room
# 0           8     2
# 1         282   387
# 2         352  1590
# 3          49   681
# 4          17    53
# 5          27     6

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نشان دهید خانه‌هایی که 0 اتاق، 1 اتاق،....، 5اتاق دارند، به طور میانگین چه قیمتی دارند.
#     </font>
# </div>

# %%
average_price_by_room = df.groupby('Room')['Price'].mean()
print(average_price_by_room)
# Out:
# Room
# 0    7.860500e+09
# 1    1.707481e+09
# 2    3.330313e+09
# 3    1.093154e+10
# 4    2.560033e+10
# 5    3.373439e+10
# Name: Price, dtype: float64

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# دیتافریم را برحسب Room و Parking گروه‌بندی کرده و میانگین قیمت هرکدام را حساب کنید.(ترجیحاً با استفاده از Aggregate کردن این کار را انجام دهید.)
#     </font>
# </div>

# %%
average_price_by_room_parking = df.groupby(['Room', 'Parking']).agg({'Price': 'mean'})
print(average_price_by_room_parking)
# Out:
#                      Price
# Room Parking
# 0    0        9.769750e+09
#      1        2.235000e+08
# 1    0        1.139678e+09
#      1        2.031369e+09
# 2    0        1.501674e+09
#      1        3.593086e+09
# 3    0        5.107865e+09
#      1        1.114662e+10
# 4    0        6.200000e+09
#      1        2.588149e+10
# 5    0        9.999000e+09
#      1        3.797286e+10

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# یک ستون جدید به نام Score به دیتافریم اصلی اضافه کنید، به طوری که مقدار آن برای هرسطر برابر است با جمع مقادیر ستون‌های Parking و Warehouse و Elevator (البته با فرض این که مقادیر ستون‌ها را در مراحل قبل از True/False به 0و1 تغییر داده‌اید.)
#     </font>
# </div>

# %%
df['Score'] = df['Parking'] + df['Warehouse'] + df['Elevator']

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         محاسبه کنید که چند درصد خانه‌هایی که مساحت کمتر از 100مترمربع دارند، دارای پارکینگ هستند؟
#     </font>
# </div>

# %%
percentage_with_parking = (len(df[df['Area'] < 100][df[df['Area'] < 100]['Parking'] == 1]) / len(df[df['Area'] < 100])) * 100
print(f"Percentage of houses with an area of less than 100 square meters that have parking spaces: {percentage_with_parking:.2f}%")
# Out:
# Percentage of houses with an area of less than 100 square meters that have parking spaces: 76.93%

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         محاسبه کنید که چند درصد از خانه‌های این دیتافریم حداقل یکی از سه ویژگی پارکینگ، انباری یا آسانسور را دارند؟
#     </font>
# </div>

# %%
percentage_with_characteristics = (len(df[(df['Parking'] == 1) | (df['Warehouse'] == 1) | (df['Elevator'] == 1)]) / len(df)) * 100
print(f"Percentage of houses with at least one of the characteristics: {percentage_with_characteristics:.2f}%")
# Out:
# Percentage of houses with at least one of the characteristics: 96.29%

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# خانه‌هایی از دیتافریم که تعداد اتاق‌های آن‌ها از 2 بیشتر است و حداقل یکی از سه ویژگی پارکینگ، انباری یا آسانسور را دارند، در قالب یک دیتافریم خروجی بدهید.    </font>
# </div>

# %%
houses_with_more_than_2_rooms_and_features = df[(df['Room'] > 2) & ((df['Parking'] == 1) | (df['Warehouse'] == 1) | (df['Elevator'] == 1))]
houses_with_more_than_2_rooms_and_features.to_csv('houses_with_more_than_2_rooms_and_features.csv', index=False)
houses_with_more_than_2_rooms_and_features
# Out:
#       Area  Room  Parking  Warehouse  Elevator                 Address  \
# 13     136     3        1          1         1             Saadat Abad
# 16     155     3        1          1         1                  Narmak
# 18     140     3        1          1         1  West Ferdows Boulevard
# 25     160     3        1          1         1                Velenjak
# 44     130     3        1          1         0                ShahrAra
# ...    ...   ...      ...        ...       ...                     ...
# 3451   180     3        1          1         0               Marzdaran
# 3455   123     3        1          1         1                Velenjak
# 3456   148     3        1          1         1               Daryan No
# 3461   133     3        1          0         1          Shahrake Gharb
# 3470   113     3        1          1         1             Ostad Moein
#
#              Price  Price(usd)  Score
# 13    1.100000e+10   366666.67      3
# 16    6.700000e+09   223333.33      3
# 18    6.400000e+09   213333.33      3
# 25    1.494500e+10   498166.67      3
# 44    5.000000e+09   166666.67      2
# ...            ...         ...    ...
# 3451  1.080000e+10   360000.00      2
# 3455  1.250000e+10   416666.67      3
# 3456  6.000000e+09   200000.00      3
# 3461  1.000000e+10   333333.33      2
# 3470  3.170000e+09   105666.67      3
#
# [820 rows x 9 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         خانه‌هایی که حداقل 2 و حداکثر 4 اتاق دارند و دارای پارکینگ هستند را در قالب یک دیتافریم خروجی دهید.
#     </font>
# </div>

# %%
houses_with_2_to_4_rooms_and_parking = df[(df['Room'] >= 2) & (df['Room'] <= 4) & (df['Parking'] == 1)]
houses_with_2_to_4_rooms_and_parking.to_csv('houses_with_2_to_4_rooms_and_parking.csv', index=False)
houses_with_2_to_4_rooms_and_parking
# Out:
#       Area  Room  Parking  Warehouse  Elevator                     Address  \
# 2       79     2        1          1         1                      Pardis
# 3       95     2        1          1         1               Shahrake Qods
# 4      123     2        1          1         1              Shahrake Gharb
# 5       70     2        1          1         0  North Program Organization
# 6       87     2        1          1         1                      Pardis
# ...    ...   ...      ...        ...       ...                         ...
# 3469    94     2        1          1         1                    Niavaran
# 3470   113     3        1          1         1                 Ostad Moein
# 3472    86     2        1          1         1          Southern Janatabad
# 3473    83     2        1          1         1                    Niavaran
# 3475   105     2        1          1         1                      Dorous
#
#              Price  Price(usd)  Score
# 2     5.500000e+08    18333.33      3
# 3     9.025000e+08    30083.33      3
# 4     7.000000e+09   233333.33      3
# 5     2.050000e+09    68333.33      2
# 6     6.000000e+08    20000.00      3
# ...            ...         ...    ...
# 3469  8.450000e+09   281666.67      3
# 3470  3.170000e+09   105666.67      3
# 3472  3.500000e+09   116666.67      3
# 3473  6.800000e+09   226666.67      3
# 3475  5.600000e+09   186666.67      3
#
# [2471 rows x 9 columns]

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# یک ستون به دیتافریم اضافه کنید و در آن حاصل تقسیم Price بر Area را ذخیره کنید، سپس دیتافریم را برحسب این ستون sort کنید. حال بررسی کنید که 50 خانه‌ی اول این دیتافریم sort شده مربوط به کدام Addressهای متمایز هستند. این Addressها را در قالب یک لیست خروجی دهید.
#     </font>
# </div>

# %%
df['Price_Per_Area'] = df['Price'] / df['Area']
df_sorted = df.sort_values(by='Price_Per_Area')
distinct_addresses_first_50 = df_sorted.head(50)['Address'].unique().tolist()
print(distinct_addresses_first_50)
# Out:
# ['Central Janatabad', 'Gheitarieh', 'Qarchak', 'Ozgol', 'Pardis', 'Parand', 'Andisheh', 'Persian Gulf Martyrs Lake', 'Shahryar', 'Northern Chitgar', 'Pasdaran', 'Malard', 'Pakdasht', 'Pishva', 'Saadat Abad', 'Shahedshahr']

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b>
#         <font color=#006bcf size=5>فاز دوم پروژه: </font>
#         <font color=#006bcf size=5>
# Data Visualization
#             </font>
#          </b>
#         <br><br>
#          <font face="IranSansX" size=3>
#         بخش تصویرسازی داده‌ها در این پروژه، به دانشجوان فرصت می‌دهد تا با استفاده از ابزارها و تکنیک‌های مختلف، داده‌های خود را به شکل‌های بصری جذاب و قابل فهم ترسیم کنند. این بخش از پروژه امکان می‌دهد تا دانشجوان با استفاده از نمودارها، نقشه‌ها، چارت‌ها و دیگر روش‌های تصویری، اطلاعات و الگوهای مهم موجود در داده‌های خود را به روشی کارآمد و شفاف برای مخاطبان مختلف به نمایش بگذارند. این فرایند نه‌تنها به دانشجوان کمک می‌کند تا داده‌های خود را بهبود دهند و بازنمایی مناسبی از آن‌ها ارائه دهند، بلکه به آن‌ها این امکان را می‌دهد تا ارتباطات قوی‌تری بین داده‌ها را ایجاد کرده و الگوها یا تفاوت‌های مهم را به دیگران به شیوه‌ای واضح و قابل فهم نشان دهند. استفاده از تصاویر و گرافیک‌های مختلف به دانشجوان کمک می‌کند تا ارتباطات خود را بهبود بخشند و به دیگران کمک کنند تا داده‌ها را با یک دید بصری جذاب و موثرتر درک کنند.
#         </font>
#         <hr/>
#         <hr/>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         <b><font color=#cf0000 size=4>نکات مهم فاز دوم</font></b>
#         <hr/>
#         <ul>
#             <li>در این فاز اجباری است که تمامی نمودارهایی که رسم می‌کنید دارای title و label و ... باشد.(جدای از این که داخل متن سوال اشاره شده یا خیر.)</li>
#             <li>همچنین لازم است که scale تمامی نمودارها را با استفاده از دستوراتی همانند xlim و ylim طوری تنظیم کنید که نمودار شکل و شمایل خوبی داشته باشد.</li>
#         </ul>
#         <img src="https://github.com/MoeeinAali/FOP2023-Python-Project-SUT/blob/main/public/pic1.jpg?raw=true" style="width:75%;">
#                 <hr>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار پراکندگی Price برحسب Area را رسم کنید.(نام هر محور را با label مشخص کنید.)
#     </font>
# </div>

# %%
df = df[df['Area'] <= 3500]

plt.figure(figsize=(10, 5))
plt.scatter(df['Area'], df['Price'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatter Diagram of Price in Terms of Area')
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نمودار قبلی را با رنگی غیر از رنگ default رسم کنید.    </font>
# </div>

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Area'], df['Price'], color='green')  # Specify the color as 'green'
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatter Diagram of Price in Terms of Area')
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار قبلی را طوری رسم کنید که نقاط با کارکتر ستاره (*) نشان داده شوند.
#     </font>
# </div>

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Area'], df['Price'], color='green', marker='*')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatter Diagram of Price in Terms of Area')
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نمودار پراکندگی Price برحسب Room را همانند نمودار قبلی با ویژگی‌های فوق به صورت یکجا رسم کنید.    </font>
# </div>

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Room'], df['Price'], color='blue', marker='*')
plt.xlabel('Room')
plt.ylabel('Price')
plt.title('Price Dispersion Chart in Terms of Room')
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار پراکندگی Price را برحسب ستون Score که خودمان در قسمت‌های قبل ایجاد کردیم رسم کنید.
#     </font>
# </div>

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Score'], df['Price'], color='red', marker='*')
plt.xlabel('Score')
plt.ylabel('Price')
plt.title('Price Scatter Chart According to Score')
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار توزیع فراوانی را برای ستون Price رسم کنید. بازه‌ی تغییرات قیمت را به 30 قسمت تقسیم کرده و در نمودار نشان دهید.
#     </font>
# </div>

# %%
df = df[df['Price'] <= 40000000000]

plt.figure(figsize=(10, 5))
plt.hist(df['Price'], bins=30, color='orange', edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Price')
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# برای نمودار قسمت قبل، نمودار تخمین چگالی توزیع هم‌زمان (KDE) را رسم کنید.(این نمودار یک تخمین صاف و پیوسته از توزیع احتمال داده‌ها را نشان می‌دهد.)    </font>
# </div>

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(df['Price'], color='purple', fill=True)
plt.xlabel('Price')
plt.ylabel('Density')
plt.title('Kernel Density Estimate (KDE) of Price')
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         توضیح دهید که کاربرد نمودار توزیع فراوانی چیست؟
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;font-size:small;">
# 	<font face="IranSansX" size=2 color=#4b4b4c>
# به طور کلی، نمودارهای توزیع فراوانی بینشی کلی در مورد ویژگی های توزیعی داده ها میدهد.
# با نمایشی بصری از نحوه توزیع مقادیر در فواصل زمانی مختلف ارائه می دهد. این به درک پراکندگی و شکل توزیع داده ها کمک می کند.
# همچنین با مشاهده شکل هیستوگرام می توان الگوهایی مانند چولگی، تقارن یا چندوجهی را در داده ها شناسایی کرد. این می تواند بینشی در مورد روابط یا روندهای اساسی ارائه دهد.
# این شکل نمودار تفاوت ها یا شباهت های بین مجموعه داده ها را برجسته می کند و مقایسه لحظه ای را آسان میسازد.
# همچنین هیستوگرام ها خلاصه ای مختصر از مجموعه داده را با نمایش طیف وسیعی از مقادیر به شیوه ای بصری جذاب ارائه می دهند. این باعث می‌شود که ویژگی‌های کلیدی داده‌ها به دیگران ارتباط برقرار کند. در اینجا مثال هایی آورده شده:
# جمعیت شناسی: نمودارهای توزیع فراوانی برای تجسم داده های جمعیت شناختی، مانند توزیع سنی یا توزیع درآمد در یک جمعیت استفاده می شود. به عنوان مثال، نمودار توزیع سنی در جمعیت یک کشور می تواند نسبت افراد در گروه های سنی مختلف را نشان دهد. این اطلاعات برای سیاستگذاران، بازاریابان و محققانی که روندهای جمعیت را مطالعه می کنند، ارزشمند است.
# کنترل کیفیت: در تولید و کنترل کیفیت، نمودارهای توزیع فراوانی برای تجزیه و تحلیل توزیع عیوب یا خطاهای محصول استفاده می شود. به عنوان مثال، هیستوگرام اندازه عیب در قطعات تولید شده می تواند به شناسایی عیوب رایج و اولویت بندی اقدامات اصلاحی برای بهبود کیفیت محصول کمک کند.
# داده های نظرسنجی: نمودارهای توزیع فراوانی برای تجسم پاسخ های نظرسنجی و داده های پرسشنامه استفاده می شود. نمودارهای توزیع فراوانی به محققان و تحلیلگران کمک می کند تا روندها و الگوهای موجود در داده های نظرسنجی را شناسایی کنند، تصمیم گیری و برنامه ریزی استراتژیک را هدایت کنند.
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# با استفاده از نمودار Pairplot برای هر دو جفت ستون موجود در دیتافریم یک نمودار پراکندگی به همراه KDE رسم کنید.
#     </font>
# </div>

# %%
sns.pairplot(df, diag_kind='kde')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# ابتدا ماتریس همبستگی (Correlation Matrix) دیتافریم را با استفاده از توابع آماده بسازید و ذخیره کنید، سپس نمودار Heatmap را بر اساس این ماتریس رسم کنید.
#     </font>
# </div>

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار Heatmap را به گونه‌ای رسم کنید که مقدار ماتریس همبستگی در هر خانه از نمودار نشان داده شود و از پالت رنگی RdYlGn برای رسم نمودار استفاده شود.
#     </font>
# </div>

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='RdYlGn', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# توضیح دهید که کاربرد Heatmap چیست؟
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;font-size:small;">
# 	<font face="IranSansX" size=2 color=#4b4b4c>
# هیت‌مپ‌ها می توانند الگوها و روندها را در داده ها با برجسته کردن مناطق با مقادیر بالا یا پایین نشان دهند. این می تواند به شناسایی خوشه ها، نقاط پرت یا مناطق مورد علاقه در مجموعه داده کمک کند. همینطور میتوانند روابط یا وابستگی های بین متغیرها را برجسته کنند. به عنوان مثال، در یک نقشه حرارتی از داده های فروش، می توانید به راحتی تشخیص دهید که کدام محصولات اغلب با هم توسط مشتریان خریداری می شوند. در زیر کاربرد هایی از این نوع نمودار آورده شده است:
#         ژنومیک: هیت‌مپ معمولاً در علوم ژنتیک برای تجسم داده های بیان ژن استفاده می شود. هر ردیف نشان دهنده یک ژن و هر ستون نشان دهنده یک نمونه است. شدت رنگ هر سلول نشان دهنده سطح بیان ژن در نمونه مربوطه است. نقشه های حرارتی به محققان کمک می کند تا الگوهای بیان ژن را در نمونه های مختلف شناسایی کنند، که می تواند بینشی در مورد فرآیندهای بیولوژیکی و مکانیسم های بیماری ارائه دهد.
# اقتصاد: در امور مالی، هیت‌مپ برای تجسم داده های بازار سهام استفاده می شود. هر ردیف نشان دهنده یک سهام و هر ستون نشان دهنده یک دوره زمانی (به عنوان مثال، روز، هفته، ماه) است. شدت رنگ هر سلول نشان دهنده درصد تغییر در قیمت سهام نسبت به یک بیس لاین است. نقشه های حرارتی به معامله گران و سرمایه گذاران اجازه می دهد تا به سرعت روندها و ناهنجاری ها را در بازار سهام شناسایی کنند و به آنها در تصمیم گیری آگاهانه کمک می کند.
# تجزیه و تحلیل وب سایت: هیت‌مپ‌ها در تجزیه و تحلیل وب سایت برای تجسم داده های تعامل کاربر استفاده می شود. به عنوان مثال، یک نقشه حرارتی از یک صفحه وب می‌تواند نشان دهد که کاربران در کجا بیشترین کلیک را دارند (هات‌اسپات‌ها) و در کجا کمترین کلیک می‌کنند (کلد‌اسپات‌ها). این نوع نمودار به طراحان وب سایت کمک می کند تا طرح و طراحی صفحات وب را برای بهبود تجربه کاربر و افزایش تعامل بهینه کنند.
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         برای ستون Parking نمودار Pie Chart را به گونه‌ای رسم کنید که هر بخش نمودار یک رنگ دلخواه از طیف سبز داشته باشد و بخشی که فراوانی کمتری دارد از نمودار explode شود و هر بخش نمودار یک label داشته باشد.
#     </font>
# </div>

# %%
parking_counts = df['Parking'].value_counts()
colors = ['limegreen', 'lightgreen']
explode = (0.1, 0)
plt.figure(figsize=(8, 8))
plt.pie(parking_counts, labels=parking_counts.index, colors=colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Parking Availability')
plt.axis('equal') 
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# توضیح دهید که کاربرد Piechart چیست؟
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;font-size:small;">
# 	<font face="IranSansX" size=2 color=#4b4b4c>
# نمودارهای دایره‌ای برای تجسم توزیع داده‌ها در جایی که بخش‌ها به یک کل کمک می‌کنند مفید هستند و معمولاً برای نشان دادن درصد یا نسبت‌های کل استفاده می‌شوند.
# در اینجا چند نمونه از استفاده از نمودار دایره ای آورده شده است:
# سهام: نمودارهای دایره ای معمولاً برای تجسم داده های سهم بازار استفاده می شوند. هر تکه از کیک نشان دهنده نسبت سهم بازار است که توسط شرکت ها یا محصولات مختلف در یک صنعت خاص در اختیار دارد. این به ذینفعان اجازه می دهد تا به سرعت موقعیت نسبی بازار بازیگران مختلف را درک کنند.
# توزیع سرمایه: نمودارهای دایره ای برای پردازش داده های تخصیص بودجه استفاده می شود که نشان می دهد چگونه وجوه در گروه ها یا بخش های مختلف توزیع می شود. به عنوان مثال، نمودار دایره ای می تواند درصدی از بودجه یک شرکت را که به حقوق، بازاریابی، تحقیق و توسعه و غیره تخصیص داده شده است، نشان دهد.
# نظرسنجی ها: نمودارهای دایره ای برای ارائه نتایج نظرسنجی ها یا نظرسنجی ها استفاده می شود که در آن پاسخ دهندگان از بین گزینه های متعدد انتخاب می کنند. هر تکه از پای نشان دهنده درصد پاسخ دهندگانی است که گزینه خاصی را انتخاب کرده اند. نمودار دایره ای مشاهده توزیع پاسخ ها و شناسایی محبوب ترین انتخاب ها را آسان می کند.
# توزیع جمعیت: نمودارهای دایره ای را می توان برای پردازش داده های جمعیت شناختی، مانند توزیع جمعیت بر اساس گروه سنی، جنسیت، یا قومیت استفاده کرد. هر بخش نشان دهنده نسبت جمعیت در یک دسته جمعیتی خاص است که به محققان و سیاستگذاران کمک می کند تا توزیع جمعیت را درک کنند.
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک نمودار سه قسمتی از نوع Pie Chart رسم کنید. هربخش از این نمودار نشان دهنده توزیع یکی از سه متغیر Warehouse , Parking , Elevator است. نمودار را به گونه‌ای رسم کنید که طیف رنگی هر متغیر با دیگری فرق کند و هر بخش نمودار دارای label مناسب باشد و بخشی که فراوانی کمتری دارد از نمودار explode شود.
#     </font>
# </div>

# %%
warehouse_counts = df['Warehouse'].value_counts()
parking_counts = df['Parking'].value_counts()
elevator_counts = df['Elevator'].value_counts()
warehouse_colors = ['lightblue', 'deepskyblue']
parking_colors = ['lightgreen', 'limegreen']
elevator_colors = ['lightcoral', 'indianred']
explode = (0.1, 0)
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.pie(warehouse_counts, labels=warehouse_counts.index, colors=warehouse_colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Warehouse')

plt.subplot(1, 3, 2)
plt.pie(parking_counts, labels=parking_counts.index, colors=parking_colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Parking')

plt.subplot(1, 3, 3)
plt.pie(elevator_counts, labels=elevator_counts.index, colors=elevator_colors, explode=explode, autopct='%1.1f%%', startangle=140)
plt.title('Elevator')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نمودار جعبه‌ای را برای ستون Price به گونه‌ای رسم کنید که رنگ آن قرمز باشد و نمودار دارای title و xlabel باشد.
#     </font>
# </div>

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Price'], patch_artist=True, boxprops=dict(facecolor='red'))
plt.title('Box Plot of Price')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
# نمودار قبلی را به گونه‌ای رسم کنید که قطر خطوط و اندازه فونت نوشته‌های نمودار را به میزان دلخواه زیاد کنید.    </font>
# </div>

# %%
plt.figure(figsize=(10, 8))
plt.boxplot(df['Price'], patch_artist=True, boxprops=dict(facecolor='red', linewidth=2),
            medianprops=dict(color='black', linewidth=2), whiskerprops=dict(linewidth=2),
            capprops=dict(linewidth=2), flierprops=dict(marker='o', markersize=8, markerfacecolor='red', linestyle='none'),
            widths=0.6)
plt.title('Box Plot of Price', fontsize=16)
plt.xlabel('Price', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار histogram را برای ستون Room رسم کنید و برای آن label و title و رنگ مناسب مشخص کنید.
#     </font>
# </div>

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Room'], bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5], color='skyblue', edgecolor='black')
plt.title('Histogram of Room', fontsize=16)
plt.xlabel('Number of Rooms', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(range(1, 6))
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         یک نمودار سه قسمتی از نوع histogram رسم کنید. هر بخش از این نمودار نشان دهنده‌ی توزیع یکی از سه متغیر Elevator , Parking , Warehouse است.  نمودار را به گونه‌ای رسم کنید که طیف رنگی هر متغیر با دیگری فرق کند و هر بخش نمودار دارای label مناسب باشد.
#     </font>
# </div>

# %%
elevator_data = df['Elevator']
parking_data = df['Parking']
warehouse_data = df['Warehouse']

plt.figure(figsize=(8, 6))
plt.hist(elevator_data, bins=10, color='blue', alpha=0.7)
plt.title('Distribution of Elevator')
plt.xlabel('Elevator')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
plt.hist(parking_data, bins=10, color='green', alpha=0.7)
plt.title('Distribution of Parking')
plt.xlabel('Parking')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
plt.hist(warehouse_data, bins=10, color='orange', alpha=0.7)
plt.title('Distribution of Warehouse')
plt.xlabel('Warehouse')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ابتدا دامنه تغییرات ستون Price را محاسبه کنید و آن را به 4 بازه مساوی با نام‌های cheap , AveUnderMean , AveUpperMean , Expensive تقسیم کنید. به هر بازه تعداد خانه‌هایی که قیمتشان در این بازه قرار دارد را نسبت دهید و در آخر نمودار countplot را برای این بازه‌ها رسم کنید.
#     </font>
# </div>

# %%
price_range = df['Price'].max() - df['Price'].min()
interval_size = price_range / 4

cheap = df['Price'].min() + interval_size
AveUnderMean = df['Price'].min() + interval_size * 2
AveUpperMean = df['Price'].min() + interval_size * 3
Expensive = df['Price'].max()

bins = [df['Price'].min(), cheap, AveUnderMean, AveUpperMean, Expensive]

df['Price_category'] = pd.cut(df['Price'], bins=bins, labels=['cheap', 'AveUnderMean', 'AveUpperMean', 'Expensive'])

interval_counts = df['Price_category'].value_counts()

plt.figure(figsize=(8, 6))
sns.countplot(x='Price_category', data=df, order=['cheap', 'AveUnderMean', 'AveUpperMean', 'Expensive'])
plt.title('Distribution of House Prices')
plt.xlabel('Price Category')
plt.ylabel('Number of Houses')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         ابتدا 2 درصد از داده‌های ستون Price را به صورت تصادفی انتخاب کنید و سپس نمودار خط‌ شکسته را برای این داده‌ها رسم کنید.(محورها دارای label باشند و رنگ نمودار قرمز باشد.)
#     </font>
# </div>

# %%
import random

num_rows = int(len(df) * 0.02)

df_reset_index = df.reset_index(drop=True)

random_indices = random.sample(range(len(df_reset_index)), num_rows)
random_prices = df_reset_index.loc[random_indices, 'Price']

plt.figure(figsize=(8, 6))
plt.plot(random_prices, linestyle='--', color='red')
plt.title('Broken Line Graph of Randomly Selected Prices')
plt.xlabel('Index')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         همانطور که میبینید نمودار قبلی ظاهر خوبی ندارد و شرط تابع بودن را نقض کرده است، داده‌های تصادفی مرحله قبل را به گونه‌ای sort کنید نمودار ما تبدیل به یک تابعی شود که اکیدا یکنوا نیست و نوسان دارد.
#     </font>
# </div>

# %%
sorted_prices = []
for i in range(num_rows):
    start_index = i * 5
    end_index = min((i + 1) * 5, num_rows)
    interval_prices = random_prices[start_index:end_index].tolist()
    random.shuffle(interval_prices)
    sorted_prices.extend(interval_prices)
plt.figure(figsize=(8, 6))
plt.plot(sorted_prices, linestyle='--', color='red')
plt.title('Broken Line Graph of Sorted Random Prices')
plt.xlabel('Index')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار قسمت قبل را به گونه‌ای رسم کنید که نقاط شکستگی نمودار با یک دایره با رنگ آبی نشان داده شوند.
#     </font>
# </div>

# %%
sorted_prices = []
breakpoints = []  
for i in range(num_rows):
    start_index = i * 5
    end_index = min((i + 1) * 5, num_rows)
    interval_prices = random_prices[start_index:end_index].tolist()
    random.shuffle(interval_prices)
    sorted_prices.extend(interval_prices)
    breakpoint = start_index + len(interval_prices) - 1
    if breakpoint < len(sorted_prices):
        breakpoints.append(breakpoint)

plt.figure(figsize=(8, 6))
plt.plot(sorted_prices, linestyle='--', color='red')
plt.scatter(breakpoints, [sorted_prices[i] for i in breakpoints], color='blue', marker='o')
plt.title('Broken Line Graph with Blue Circle Markers at Breakpoints')
plt.xlabel('Index')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار خط شکسته‌ی Price(USD) برحسب Area را رسم کنید.
#     </font>
# </div>

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Area'], df['Price(usd)'], marker='o', linestyle='--', color='blue')
plt.title('Broken Line Chart of Price(USD) by Area')
plt.xlabel('Area')
plt.ylabel('Price(USD)')
plt.grid(True)
plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         به نمودار رسم شده در قسمت قبل، نمودار روند تغییرات مرتبه اول(خطی) را اضافه کنید.(برای پیدا کردن ضرایب رگرسیون می‌توانید از تابع polyfit در کتابخانه numpy استفاده کنید.)
#     </font>
# </div>

# %%
x = df['Area']
y = df['Price']

coefficients = np.polyfit(x, y, 1)
poly = np.poly1d(coefficients)

plt.figure(figsize=(10, 6))
plt.scatter(x, y, marker='o', color='blue', label='Data')

plt.plot(x, poly(x), label='Trend Line')

plt.title('Scatter Plot with First-order Trend Line')
plt.xlabel('Area')
plt.ylabel('Price')

plt.legend()

plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار روند تغییرات خطی که در قسمت قبل رسم کردیم را به صورت خط‌چین با رنگ قرمز رسم کنید.
#     </font>
# </div>

# %%
x = df['Area']
y = df['Price']

coefficients = np.polyfit(x, y, 1)
poly = np.poly1d(coefficients)

plt.figure(figsize=(10, 6))
plt.scatter(x, y, marker='o', color='blue', label='Data')

plt.plot(x, poly(x), color='red', linestyle='--', label='Trend Line')

plt.title('Scatter Plot with First-order Trend Line')
plt.xlabel('Area')
plt.ylabel('Price')

plt.legend()

plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         نمودار Barplot را برای ستون Price برحسب ستون Room رسم کنید.(نمودار باید دارای title و label مناسب باشد.)
#     </font>
# </div>

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.barplot(x='Room', y='Price', data=df)

plt.title('Average Price by Room')
plt.xlabel('Room')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;line-height:250%;font-size:small;">
# 	<font face="IranSansX" size=3>
#         توضیح دهید که کاربرد Barplot چیست؟
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="font-face:IranSansX;direction:rtl;font-size:small;">
# 	<font face="IranSansX" size=2 color=#4b4b4c>
# بارپلات‌ها برای تجسم توزیع یا مقایسه داده های دسته بندی مفید هستند.
# مقایسه: نمودارهای نواری معمولاً برای مقایسه مقادیر دسته های مختلف استفاده می شود. به عنوان مثال، مقایسه ارقام فروش در ماه های مختلف، مقایسه عملکرد محصولات مختلف، یا مقایسه میانگین قیمت خانه ها در محله های مختلف.
# توزیع: نمودارهای نواری همچنین می توانند توزیع داده ها را در هر دسته نشان دهند. به عنوان مثال، نشان دادن فراوانی پاسخ های مختلف در یک نظرسنجی، یا تعداد وقوع انواع مختلف رویدادها.
# روند زمانی: نمودارهای نواری می توانند روندها را در طول زمان یا در بین دسته ها نشان دهند. به عنوان مثال، رسم میانگین دمای هر ماه برای تجسم روندهای فصلی، یا ترسیم تعداد بازدیدکنندگان وب سایت در روز برای شناسایی الگوها.
# نسبت: نمودارهای نوار می توانند نسبت ها یا درصدها را در هر دسته نمایش دهند. به عنوان مثال، نشان دادن سهم بازار شرکت های مختلف در یک صنعت، یا درصد دانش آموزانی که درجات مختلف را کسب کرده اند.
#     </font>
# </div>
